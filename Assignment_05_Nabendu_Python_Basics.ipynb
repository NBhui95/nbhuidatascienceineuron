# %% [markdown]
# 1. What does an empty dictionary's code look like?

# %%
                                                        ###  Answer  ###                 
'''

An empty dictionary's code look like curly brackets: {}

''' 

dict1 = {}
print(type(dict1))
# Out:
# <class 'dict'>

# %% [markdown]
# 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
                                                        ###  Answer  ###                 
'''

The value of a dictionary value with the key 'foo' and the value 42 is {'foo': 42}

'''
{'foo': 42}
# Out:
# {'foo': 42}

# %% [markdown]
# 3. What is the most significant distinction between a dictionary and a list?

# %%
                                                        ###  Answer  ###                 
'''

List => Items in list are Ordered.
Dictionary => Items in dictionary are Unordered.

'''

# %% [markdown]
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
                                                        ###  Answer  ###                 
'''

It will give an key error because 'foo' is not present:

KeyError: 'foo'

'''

spam = {'bar':100}
spam['foo']

# %% [markdown]
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %%
                                                        ###  Answer  ###                 
'''

There is no differnce, both check if 'cat' is key of the dictionary and if its a key, returns True.

'''

spam ={'cat':100}
print('cat' in spam)                      

spam ={'cat':100}
print('cat' in spam.keys())
# Out:
# True
# True

# %% [markdown]
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %%
                                                        ###  Answer  ###                 
'''

It will check if 'cat' is key of the dictionary and if its a key, returns True.

spam.values() checks whether there is a value 'cat' for one of the keys in spam and if its not a value, returns False.

'''

spam ={'cat':100}
print('cat' in spam) 

spam ={'cat':100}
print('cat' in spam.values())
# Out:
# True
# False

# %% [markdown]
# 7. What is a shortcut for the following code?
#
#  if 'color' not in spam:
#
#  spam['color'] = 'black'

# %%
                                                        ###  Answer  ###                 
spam ={'cat':100}
spam.setdefault('color','black')
print(spam)
# Out:
# {'cat': 100, 'color': 'black'}

# %% [markdown]
# 8. How do you "pretty print" dictionary values using which module and function?

# %%
                                                        ###  Answer  ###                 
'''

pprint.pprint()

'''

import pprint
dict1 = [ {'Name': 'ABC', 'Age': '30', 'Country': 'India'},
  {'Name': 'DEF', 'Age': '60', 'Country': 'USA'},
  {'Name': 'GHI', 'Age': '25', 'Country': 'Nepal'}
]
pprint.pprint(dict1)
print(dict1)
# Out:
# [{'Age': '30', 'Country': 'India', 'Name': 'ABC'},
#  {'Age': '60', 'Country': 'USA', 'Name': 'DEF'},
#  {'Age': '25', 'Country': 'Nepal', 'Name': 'GHI'}]
# [{'Name': 'ABC', 'Age': '30', 'Country': 'India'}, {'Name': 'DEF', 'Age': '60', 'Country': 'USA'}, {'Name': 'GHI', 'Age': '25', 'Country': 'Nepal'}]

# %%
.
