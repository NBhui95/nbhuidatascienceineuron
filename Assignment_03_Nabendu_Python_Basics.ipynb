# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %%
                                                        ###  Answer  ###                 
'''

Advantageous of Functions in any programs:
1. Reduction of duplicacy of writing similar codes in any program.
2. It's frequently difficult to read a large program, breaking the code down into smaller functions keeps the program structured, understandable, and reusable.
3. We can use functions any number of times.

'''

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?

# %%
                                                        ###  Answer  ###                 
'''

When does the code in a function run: 
=> When it's called.

'''

# %% [markdown]
# 3. What statement creates a function?

# %%
                                                        ###  Answer  ###                 
'''

def statement creates/defines a function.

'''
def sum1(a,b):
  c=a+b
  print("Sum of two numbers: ",c)

sum1(2,3)
# Out:
# Sum of two numbers:  5

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %%
                                                        ###  Answer  ###                 
'''

Function => A function is a piece of code which enhanced the reusability of particular code. Through def - we ar edefining the Function.

Function Call => Function call means calling the function.

'''

def sum1(a,b):      # Function
  c=a+b
  print(f"Sum of {a} and {b} is {c} ")

sum1(2,3)        #Function Call
# Out:
# Sum of 2 and 3 is 5

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %%
                                                        ###  Answer  ###                 
'''

There's only one global Python scope in a Python Program.

A local scope is created whenever a function is called.

Actually, if we operate with the same variable name inside and outside of a function, 
Python will treat them as two separate variables, the global scope is in outside the function and the local scope is in inside the function.

'''

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?

# %%
                                                        ###  Answer  ###                 
'''

When the function call returns, the variables in local scope are destroyed.

'''

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %%
                                                        ###  Answer  ###                 
'''

A return is a value that a function returns to the calling script or function when it completes its task.

A return value can be used as part of an expression.

'''

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %%
                                                        ###  Answer  ###                 
'''

If the funtion does not have a return statement it will not return anything.

'''

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?

# %%
                                                        ###  Answer  ###                 
'''

To make a function variable as a global variable we can use the global keyword to declare which variables are global.

'''

def function01():
  global a
  a = "Very Interserting Language."

function01()

print("Python is " + a)
# Out:
# Python is Very Interserting Language.

# %% [markdown]
# 10. What is the data type of None?

# %%
                                                        ###  Answer  ###                 
'''

The data type of None is NoneType.

'''

a=None
print(type(a))
# Out:
# <class 'NoneType'>

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?

# %%
                                                        ###  Answer  ###                 
'''

The import statement imports a module named areallyourpetsnamederic. 

'''

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %%
                                                        ###  Answer  ###                 
'''

This function can be called with spam.bacon().


'''

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %%
                                                        ###  Answer  ###                 
'''

We can use try clause to save a program from crashing.

'''

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %%
                                                        ###  Answer  ###                 
'''

The code that could potentially cause an error goes in the try clause.

The code that executes if an error happens goes in the except clause.

'''

# %% [markdown]
# .
